# %% [markdown]
# ## SHAP Explanation

# %%
# %pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (0.48.0)
# Requirement already satisfied: numpy in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from shap) (2.2.4)
# Requirement already satisfied: scipy in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from shap) (1.15.2)
# Requirement already satisfied: scikit-learn in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from shap) (1.7.0)
# Requirement already satisfied: pandas in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from shap) (2.2.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\zsolf\appdata\roaming\python\python312\site-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from shap) (0.62.0)
# Requirement already satisfied: cloudpickle in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from shap) (4.15.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from numba>=0.54->shap) (0.45.0)
# Requirement already satisfied: colorama in c:\users\zsolf\appdata\roaming\python\python312\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zsolf\appdata\roaming\python\python312\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\zsolf\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\zsolf\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import shap
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

#import model from data-prediction.ipynb
import joblib
xgb_model = joblib.load('../assets/xgb_model.pkl')

#load data
X = pd.read_csv('../assets/X.csv')
X
# Out:
#       Age  Gender  Family_history_overweight  High_caloric_food  \
# 0      21       1                          1                  0
# 1      21       1                          1                  0
# 2      23       0                          1                  0
# 3      27       0                          0                  0
# 4      22       0                          0                  0
# ...   ...     ...                        ...                ...
# 2106   21       1                          1                  1
# 2107   22       1                          1                  1
# 2108   23       1                          1                  1
# 2109   24       1                          1                  1
# 2110   24       1                          1                  1
#
#       Veggie_consumption_freq  Main_meals_count  Food_between_meals_freq  \
# 0                           1                 1                        1
# 1                           3                 1                        1
# 2                           1                 1                        1
# 3                           3                 1                        1
# 4                           1                 0                        1
# ...                       ...               ...                      ...
# 2106                        3                 1                        1
# 2107                        3                 1                        1
# 2108                        3                 1                        1
# 2109                        3                 1                        1
# 2110                        3                 1                        1
#
#       Smokes  Water_consumption  Monitors_calories  Physical_activity  \
# 0          0                  1                  0                  0
# 1          1                  2                  1                  4
# 2          0                  1                  0                  3
# 3          0                  1                  0                  3
# 4          0                  1                  0                  0
# ...      ...                ...                ...                ...
# 2106       0                  1                  0                  3
# 2107       0                  1                  0                  2
# 2108       0                  1                  0                  2
# 2109       0                  2                  0                  2
# 2110       0                  2                  0                  2
#
#       Screen_time  Alcohol_consumption_freq  Transportation_mode  \
# 0               1                         0                    4
# 1               0                         1                    4
# 2               1                         2                    4
# 3               0                         2                    1
# 4               0                         1                    4
# ...           ...                       ...                  ...
# 2106            1                         1                    4
# 2107            1                         1                    4
# 2108            1                         1                    4
# 2109            1                         1                    4
# 2110            1                         1                    4
#
#       Obesity_level
# 0                 1
# 1                 1
# 2                 1
# 3                 2
# 4                 3
# ...             ...
# 2106              6
# 2107              6
# 2108              6
# 2109              6
# 2110              6
#
# [2111 rows x 15 columns]

# %%
array_y = X.Obesity_level
array_X = X.drop("Obesity_level", axis=1)

# Stratified train-test split
X_train, X_test, y_train, y_test = train_test_split(
    array_X, array_y, test_size=0.2, random_state=20250928, stratify=array_y
)

print("Shape of training set\t", X_train.shape, y_train.shape)
print("Shape of test set\t", X_test.shape, y_test.shape)
# Out:
# Shape of training set	 (1688, 14) (1688,)
# Shape of test set	 (423, 14) (423,)

# %%
explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_test)
# Plot SHAP values for the most obese class (class 6)
shap.summary_plot(shap_values[:, :, 6], X_test)

# %%
shap.dependence_plot("Veggie_consumption_freq", shap_values[:, :, 6], X_test,interaction_index="Gender")
#Female = 1, Male = 0

# %%
# Show force plot for the first sample and class 6 (most obese)
shap.plots.force(
	explainer.expected_value[6],           # expected value for class 6
	shap_values[0, :, 6],                  # SHAP values for first sample, class 6
	X_test.iloc[0, :],                     # feature values for first sample
	matplotlib=True
)
